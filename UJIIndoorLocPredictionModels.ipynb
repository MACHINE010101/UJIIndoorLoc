# %% [markdown]
# # Data Analytics & Machine Learning - Miniproject
# **Author: Eduard Pascale**
#
# **Date: 1/05/2023**
#
# ## Short Intro
#
# In the miniproject we have to tackle down a problem regarding [DAL module](https://fhict.instructure.com/courses/13020/assignments/218989?module_item_id=915417), as agreed with the teacher I had to choose between two datasets to dive into and get the most out of it. I choose to work with UJIIndoorLoc dataset because it's a dataset which is relevant for me, in my industry project I have to work with a similar problem therefore I hope this dataset will give me the training that I need.
#
# In this report, I will explain how to organize and analyze data in a way that helps make better decisions. I'll go over the steps to prepare data for analysis, explore the data to find patterns, and create a data model that can predict future outcomes. To show how this works, I'll use a set of data provided by my teacher. I'll also explain each step of the process in detail, so I can learn how to improve my data modeling skills.
#
# ## Insights 💡
#
# **Here are the insights from the analysis:**
#
#     What is the size of the dataset? The size of the dataset is 21048 x 529.
#     Covers a surface of 108703m 2 including 3 buildings with 4 or 5 floors.
#     Data were collected by more than 20 users using 25 different models of mobile devices.
#
# **Based on the EDA visualizations, here are some additional insights:**
#
#     Space 0 is the most used space in most of the buildings.
#     Building no. 2 has the most samples points.
#     There is almost an equal amount of samples in each floor.
#     On the last floors there are no samples registered.
#
# ## UJIIndoorLoc
#
# The [UJIIndoorLoc Data Set](https://archive.ics.uci.edu/ml/datasets/UJIIndoorLoc) is a collection of WiFi signals data collected from access points placed in different indoor locations, such as offices, classrooms, and corridors. The data has been preprocessed to extract a set of features related to signal strength, position, and orientation, and it includes measurements of signal strengths from 520 access points. The goal of the dataset is to predict the indoor location of a person based on the received WiFi signals. The dataset has 19,937 instances and 529 features, making it a useful resource for indoor localization and navigation tasks, including classification, clustering, and regression.
#
# source: https://archive.ics.uci.edu/ml/datasets/UJIIndoorLoc
#
# In the machine learning repository, this dataset provides relevant papers for further study. As my first initiative, I'm going to look at a conference paper titled ["UJIIndoorLoc: A new multi-building and multi-ﬂoor database for WLAN ﬁngerprint-based indoor localization problems"](https://www.researchgate.net/publication/283894296_UJIIndoorLoc_A_new_multi-building_and_multi-floor_database_for_WLAN_fingerprint-based_indoor_localization_problems)
#
# <a id="atribute"></a>
# **Atribute Information:**
# * Attribute 001 (WAP001): Intensity value for WAP001. Negative integer values from -104 to 0 and +100. Positive value 100 used if WAP001 was not detected. (dBm)
# * Attribute 520 (WAP520): Intensity value for WAP520. Negative integer values from -104 to 0 and +100. Positive Vvalue 100 used if WAP520 was not detected. (dBm)
# * Attribute 521 (Longitude): Longitude. Negative real values from -7695.9387549299299000 to -7299.786516730871000
# * Attribute 522 (Latitude): Latitude. Positive real values from 4864745.7450159714 to 4865017.3646842018.
# * Attribute 523 (Floor): Altitude in floors inside the building. Integer values from 0 to 4.
# * Attribute 524 (BuildingID): ID to identify the building. Measures were taken in three different buildings. Categorical integer values from 0 to 2.
# * Attribute 525 (SpaceID): Internal ID number to identify the Space (office, corridor, classroom) where the capture was taken. Categorical integer values.
# * Attribute 526 (RelativePosition): Relative position with respect to the Space (1 - Inside, 2 - Outside in Front of the door). Categorical integer values.
# * Attribute 527 (UserID): User identifier (see below). Categorical integer values.
# * Attribute 528 (PhoneID): Android device identifier (see below). Categorical integer values.
# * Attribute 529 (Timestamp): UNIX Time when the capture was taken. Integer value.
#
# ## Relevant Papers
#
# #### IUJIIndoorLoc: A new multi-building and multi-floor database for WLAN fingerprint-based indoor localization problems
#
# One of common thing that many application wants to make use of is automatic user localization. This works by
# using an electronic device, usually a mobile phone to compute the user latitude, longitude and altitude.
# Many problems occur in indoor settings, we cannot make use of GPS sensor to locate a user because GPS signal gets lost in indoor environments.
#
# Many people have tried to make use of WLANs, which is especially a good approach because it doesn't require any extra equipment and can be found on most smartphones plus WLANs are now ubiquitous. WLAN Fingerprint-based positioning systems are based on the [Received Signal Strength Indicator (RSSI)](https://en.wikipedia.org/wiki/Received_signal_strength_indicator) value, a radio map of the area where the users should be detected is constructed and later the user obtains the signal strength of all visible access points of the WLAN.
#
# One important draw-back in this field is the lack of a common database for comparison purposes, **the UJIIndoorLoc database is presented to overcome this gap.**
#
# UJIIndoorLoc database contains characteristics such as:
# * Covers a surface of 108703m 2 including 3 buildings with 4 or 5 floors
# * The number of different places is 933
# * 21049 sampled points have been captured: 19938 for training/learning and 1111 for validation/testing
# * Validation (or testing) samples were taken 4 months after Training ones.
# * The number of different wireless access points (WAPs) appearing in the database is 520
# * Data were collected by more than 20 users using 25 different models of mobile devices
#
# This work is based on an infrastructure-less approache, mainly taking advantage of the powerful mobile phone
# sensors.
#
# #### UJIIndoorLoc DATABASE DESCRIPTION
#
# The whole database contains 21049 records, each record is directly related to 529 numeric elements:
#
# * 001-520 RSSI levels (dBm)
# * 521-523 Real world coordinates of the sample points
# * 524 BuildingID
# * 525 SpaceID
# * 526 Relative position with respect to SpaceID
# * 527 UserID
# * 528 PhoneID
# * 529 Timestamp
#
# A total number of 520 WAPs appear in the database and the 520-element vector from each record contains the raw intensity levels of the detected WAPs from a single WiFiscan. One scan cannot capture the adresses of every WAP possible, the unrelated WAP will be filled with an artificial RSSI value of +100dBm. The paper also mention that the main factors that affects the number of WAPs reported by WIFi scan
# are location and the phone model.
#
# ![image.png](attachment:image.png)
# Fig. 1. Frequency distribution of the Number of WAPs that are detected on
# a single capture.
#
# Real world coordinates of the sample points contains the longitude and latitude coordinates and the floor of the building. BuildingID coresponds to the building in which the capture was taken. SpaceID cointais one integer values to identify the particular space office, lab, etc. where the capture was taken.The other vector positions are more or less self-explanatory.
#
# The database is split into two subsets: the **training subset** and the **validation subset**.
#
# In the training subset, the reference points are these points above captured by, at least, two users.
# In the validation subset, the measures were taken as would happen in a real localization system and because of this SpaceID and Relative position are not stored in records.
#
# #### Baseline
#
# The objective of this work was not to provide an accurate indoor positioning system, the objective is to provide an objective database which can be used for comparing positioning systems and other algorithms based on WLAN-fingerprinting.
#
# #### REFERENCES
#
# [1] Torres-Sospedra, J., Montoliu, R., Martínez-Usó, A., Lázaro-Gredilla, M., Huerta, J., & Belmonte, Ò. (2014). UJIIndoorLoc: A new multi-building and multi-floor database for WLAN fingerprint-based indoor localization problems. In 2014 International Conference on Indoor Positioning and Indoor Navigation (IPIN) (pp. 261-270). IEEE.
#
# ## What is my goal?
#
# I want to create a machine learning model that can accurately predict the location of devices inside buildings using WLAN fingerprinting. The objective is to estimate the building, floor and coordinates (latitude and longitude).
#
# ## Research Questions
#
# What is the best machine learning algorithm for indoor localization predictions?
#
# Which phones are used by which users?
#
# What are Graph Neural Networks and how graph operate?
#
# ## Context Diagram
#
# This diagram shows the steps involved in building a machine learning model for indoor localization using the UJIIndoorLoc dataset.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### What are Graph Neural Networks, Bipartite Graphs and how do they work?
#
# As with my own understanding graph neural networks are a machine learning model that is able to work with graphs data types. (Graphs abundance of nodes that are connected through what they call it links). The model tries to understand the patterns and relationships that occur in the graph as well as the graph as a whole (structure).

# %% [markdown]
# A bipartite graph is a type of a graph where the nodes are split apart into 2 different subsets, all the connections are between nodes from one subset to nodes from the other subset, there are no connection in the same subset. ANother good thumb rule is an undirected graph is bipartite if and only if it does not contain an odd cycle.
# An odd cycle is a cycle where is starts from the same node and it ends in the same node, visiting different nodes in between and it has an odd number of nodes.

# %% [markdown]
# ## Loading the libraries
#
# I first load some libraries which provides different methods, as they are required throughout the entire process.

# %%
import numpy as np  # import auxiliary library, typical idiom
import pandas as pd  # import the Pandas library, typical idiom
import seaborn as sns
import math
import matplotlib.pyplot as plt
import xgboost as xg
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Now, I selectively import the relevant classes and functions from `sklearn`
# [(_SciKit Learn_, a Python library for machine learning)](http://scikit-learn.org/.)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score, confusion_matrix, classification_report
from sklearn.multioutput import MultiOutputRegressor, MultiOutputClassifier
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Color paletter for data exploration.

# %%
custom_palette = ['#8390FA', '#567568', '#242038', '#654F6F', '#D4E4BC']

# %% [markdown]
# ## Datasets
#
# This is the step where I get to know my data for the first time after the research.

# %%
df_train = pd.read_csv("Data/trainingData.csv")
df_val = pd.read_csv("Data/validationData.csv")

# %%
df_train.head(5)
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009
# 0     100     100     100     100     100     100     100     100     100  \
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106  \
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
df_val.head(5)
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009
# 0     100     100     100     100     100     100     100     100     100  \
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID
# 0     100  ...     100 -7515.916799  4.864890e+06      1           1        0  \
# 1     100  ...     100 -7383.867221  4.864840e+06      4           2        0
# 2     100  ...     100 -7374.302080  4.864847e+06      4           2        0
# 3     100  ...     100 -7365.824883  4.864843e+06      4           2        0
# 4     100  ...     100 -7641.499303  4.864922e+06      2           0        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %%
df_train.shape
# Out:
# (19937, 529)

# %%
df_val.shape
# Out:
# (1111, 529)

# %%
l1 = len(df_train)
l2 = len(df_val)
l1 + l2
# Out:
# 21048

# %% [markdown]
# The training set contains 199937 rows while the validation set contains 1111 rows and both of them contain 529 columns as described above.

# %%
df_train.columns
# Out:
# Index(['WAP001', 'WAP002', 'WAP003', 'WAP004', 'WAP005', 'WAP006', 'WAP007',
#        'WAP008', 'WAP009', 'WAP010',
#        ...
#        'WAP520', 'LONGITUDE', 'LATITUDE', 'FLOOR', 'BUILDINGID', 'SPACEID',
#        'RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'],
#       dtype='object', length=529)

# %% [markdown]
# The columns of the dataset whihc are also described in the conferance paper.

# %%
df = pd.concat([df_train, df_val])

# %%
df.shape
# Out:
# (21048, 529)

# %% [markdown]
# I choose to concatinate the sets because I want to use more data for training, by doing this can potentially improve the model's performance, as it has more examples to learn from. At the same time this is required because It may be necessary to perform data preprocessing. Since the validation set is 5% of the total data I merge both, randomize and get 20% for testing (80-20 split).

# %%
df.isnull().sum()
# Out:
# WAP001              0
# WAP002              0
# WAP003              0
# WAP004              0
# WAP005              0
#                    ..
# SPACEID             0
# RELATIVEPOSITION    0
# USERID              0
# PHONEID             0
# TIMESTAMP           0
# Length: 529, dtype: int64

# %%
df.dtypes
# Out:
# WAP001              int64
# WAP002              int64
# WAP003              int64
# WAP004              int64
# WAP005              int64
#                     ...
# SPACEID             int64
# RELATIVEPOSITION    int64
# USERID              int64
# PHONEID             int64
# TIMESTAMP           int64
# Length: 529, dtype: object

# %% [markdown]
# ## Data Exploration
#
# This is where I will try to analyze the data and find interesting facts. I'm going to see what is the relationship between different features that I plot. In order to choose what plot is most suitable for visualization I made use of a [webiste](https://www.data-to-viz.com/) that helps you in finding the best plot for your data.
# Here I make use of [seabor](https://seaborn.pydata.org/) to plot.

# %% [markdown]
# **Which phones are used by which users?**

# %%
df.groupby('USERID')['PHONEID'].unique()
# Out:
# USERID
# 0     [0, 13, 2, 12, 20, 21, 4, 9, 15, 5, 14]
# 1                                        [14]
# 2                                        [23]
# 3                                        [16]
# 4                                        [18]
# 5                                         [3]
# 6                                        [19]
# 7                                         [6]
# 8                                         [1]
# 9                                        [14]
# 10                                        [8]
# 11                                       [13]
# 12                                       [24]
# 13                                       [17]
# 14                                        [7]
# 15                                       [11]
# 16                                       [14]
# 17                                       [22]
# 18                                       [10]
# Name: PHONEID, dtype: object

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='BUILDINGID', data=df, palette=custom_palette)
plt.xlabel('Building ID')
plt.ylabel('Count')
plt.title('Count of Samples per Building')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='FLOOR', data=df, palette=custom_palette)
plt.xlabel('Floor')
plt.ylabel('Count')
plt.title('Count of Samples per Floor')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
grouped = df.groupby('BUILDINGID')['FLOOR'].unique()
plt.figure(figsize=(8, 6))
sns.barplot(x=grouped.index, y=grouped.apply(len), palette=custom_palette)
plt.xlabel('Building ID')
plt.ylabel('Number of Floors')
plt.title('Number of Floors in Each Building')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='RELATIVEPOSITION', data=df, palette=custom_palette)
plt.xlabel('Relative Position')
plt.ylabel('Count')
plt.title('Count of Samples per Relative Position')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='FLOOR', data=df, palette=custom_palette)
plt.xlabel('Floor')
plt.ylabel('Count')
plt.title('Count of Samples per Floor')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
n = 10;
top_space_ids = df['SPACEID'].value_counts().nlargest(n).index
filtered_df = df[df['SPACEID'].isin(top_space_ids)]
plt.figure(figsize=(10, 6))
sns.countplot(x='SPACEID', data=filtered_df, palette=custom_palette)
plt.xlabel('SPACEID')
plt.ylabel('Count')
plt.title(f'Top {n} Most Frequent SPACEID')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Samples Analysis by Floor & Building
#
# 💡 One greate insight that I gained from these plots is the shape of the buildings.

# %%
df_sorted = df.sort_values(by=['TIMESTAMP'])
buil0 = df_sorted[df_sorted["BUILDINGID"] == 0]
b0f0 = buil0[buil0['FLOOR'] == 0]

plt.figure(figsize=(8, 6))
sns.scatterplot(x='LATITUDE', y='LONGITUDE', hue='RELATIVEPOSITION', data=b0f0, palette=custom_palette)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Scatter Plot of Latitude vs Longitude (Bulding 1 Floor 0)')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
b0f3 = buil0[buil0['FLOOR'] == 3]

plt.figure(figsize=(8, 6))
sns.scatterplot(x='LATITUDE', y='LONGITUDE', hue='RELATIVEPOSITION', data=b0f3, palette=custom_palette)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Scatter Plot of Latitude vs Longitude (Bulding 1 Floor 3)')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
buil1 = df_sorted[df_sorted["BUILDINGID"] == 1]
b1f0 = buil1[buil1['FLOOR'] == 0]

plt.figure(figsize=(8, 6))
sns.scatterplot(x='LATITUDE', y='LONGITUDE', hue='RELATIVEPOSITION', data=b1f0, palette=custom_palette)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Scatter Plot of Latitude vs Longitude (Bulding 2 Floor 0)')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
b1f3 = buil1[buil1['FLOOR'] == 3]

plt.figure(figsize=(8, 6))
sns.scatterplot(x='LATITUDE', y='LONGITUDE', hue='RELATIVEPOSITION', data=b1f3, palette=custom_palette)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Scatter Plot of Latitude vs Longitude (Bulding 2 Floor 3)')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
buil2 = df_sorted[df_sorted["BUILDINGID"] == 2]
b2f0 = buil2[buil2['FLOOR'] == 0]

plt.figure(figsize=(8, 6))
sns.scatterplot(x='LATITUDE', y='LONGITUDE', hue='RELATIVEPOSITION', data=b2f0, palette=custom_palette)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Scatter Plot of Latitude vs Longitude (Bulding 3 Floor 0)')
plt.show()

# %% [markdown]
# ## [Go to Atributes](#atribute)

# %%
b2f4 = buil2[buil2['FLOOR'] == 4]

plt.figure(figsize=(8, 6))
sns.scatterplot(x='LATITUDE', y='LONGITUDE', hue='RELATIVEPOSITION', data=b2f4, palette=custom_palette)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Scatter Plot of Latitude vs Longitude (Bulding 3 Floor 4)')
plt.show()

# %% [markdown]
# ## Data Preprocessing
#
# Before I'm going to modify the data for the model, I'm going to make a copy that we can use for data exploration.

# %%
df_copy = df.copy()
df_copy.head(5)
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009
# 0     100     100     100     100     100     100     100     100     100  \
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106  \
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %% [markdown]
# ### Dropping unncessary columns

# %%
df_train.drop(columns = ["RELATIVEPOSITION", "USERID", "PHONEID", "TIMESTAMP"], inplace=True)
df_val.drop(columns = ["RELATIVEPOSITION", "USERID", "PHONEID", "TIMESTAMP"], inplace=True)

# %% [markdown]
# ### Normalization
#
# Normalizing the data helps prevent bias towards features with larger scales, ensuring that all features contribute equally to the analysis or model training
#
# The RSSI values range from -104 to 0 and +100 for no signal detected values. I'm going to make a new scale from 0 to 1, where 0 means not detected and 1 means a high RSSI value.
#
# #### Notes
# I tried many scales to work with but the one above seems the most suitable one, I tested different scales using an XGBoost model.
#
# **Observations:**
#
#     Scale min 0 max 100 no signal 0 I got negative R^2 values and accuracy about 20%.
#     Scale min 0 max 1 no signal 0 I got negative R^2 values and accuracy about 25%.
#     Scale min 0 max 1 no signal -1 I got negative R^2 values and accuracy about 30%.
#     Scale min 0.25 max 1 no signal 0 I got positive R^2 values and accuracy about 90%.

# %%
def normalize(x, xmin, xmax, a, b):
    numerator = x - xmin
    denominator = xmax - xmin
    multiplier = b - a
    ans = (numerator/denominator)*multiplier + a
    return ans

# %%
sig_min = -104
sig_max = 0
tar_min = 0.25
tar_max = 1.0
no_sig = 100
def normalize_wifi(num):
    ans = 0
    num = float(num)
    if math.isclose(num, no_sig, rel_tol=1e-3):
        return 0
    else:
        ans = normalize(num, sig_min, sig_max, tar_min, tar_max)
        return ans

# %%
wifi_cells_train = df_train.columns[:519]
wifi_cells_val = df_val.columns[:519]

# %%
for i in wifi_cells_train:
    df_train[i] = df_train[i].apply(normalize_wifi)
    
for i in wifi_cells_val:
    df_val[i] = df_val[i].apply(normalize_wifi)

# %% [markdown]
# The same will go for latitude and longitude.

# %%
lat_min = 4864745.7450159714
lat_max = 4865017.3646842018
tarmin = 0
tarmax = 1
def normalize_lat(num):
    num = float(num)
    ans = normalize(num, lat_min, lat_max, tarmin, tarmax)
    return ans

# %%
long_min = -7695.9387549299299000
long_max = -7299.786516730871000
tarmin = 0
tarmax = 1
def normalize_long(num):
    num = float(num)
    ans = normalize(num, long_min, long_max, tarmin, tarmax)
    return ans

# %%
df_train["LATITUDE"] = df_train["LATITUDE"].apply(normalize_lat)
df_train["LONGITUDE"] = df_train["LONGITUDE"].apply(normalize_long)

df_val["LATITUDE"] = df_val["LATITUDE"].apply(normalize_lat)
df_val["LONGITUDE"] = df_val["LONGITUDE"].apply(normalize_long)

# %% [markdown]
# ## Data Modeling
#
# In data modeling, the goal is to capture the underlying relationships and patterns within the data, enabling the model to generalize and make accurate predictions on new, unseen data. For this data and problem, I'm going to try different training tehniques.
#
# ### Select the data
#
# Let's try to predict `LATITUDE, LONGITUDE, BUILDINGID, FLOOR` by training multiple random forest model on the data.
#
# ### Train-Test split
#
# X contains the releveant features for this prediction, later we are going to find out what are the most important features.

# %%
X_train = df_train[wifi_cells_train]
X_test = df_val[wifi_cells_val]

# %%
y_train = df_train[["LATITUDE", "LONGITUDE", "BUILDINGID", "FLOOR"]]
y_test = df_val[["LATITUDE", "LONGITUDE", "BUILDINGID", "FLOOR"]]

# %% [markdown]
# ## Building a XGBoostRegressor and XGBoostClassifier
#
# An XGBoost regressor is a machine learning model that is used for regression tasks. It is designed to predict continuous numerical values based on input features. The algorithm works by creating an ensemble of weak prediction models (typically decision trees) and iteratively improving them by minimizing a loss function. XGBoost uses gradient boosting, which means that each subsequent model in the ensemble is trained to correct the mistakes made by the previous models. This iterative process continues until the algorithm converges to a final prediction model.
#
# An XGBoost classifier, on the other hand, is used for classification tasks. It is designed to predict discrete class labels or probabilities of different classes based on input features. Similar to the regressor, XGBoost classifier also creates an ensemble of weak prediction models (decision trees) and improves them iteratively through gradient boosting. The algorithm optimizes a specific loss function based on the predicted class probabilities and the true class labels. It can handle multi-class classification problems and binary classification problems.
#
# [source](https://xgboost.readthedocs.io/en/stable/)

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear',
                  n_estimators = 10, seed = 123)

xgb_c = xg.XGBClassifier()

mtl_xgbr = MultiOutputRegressor(xgb_r)
mtl_xgbc = MultiOutputClassifier(xgb_c)

# %% [markdown]
# _n_estimators = 10_ number of boosting rounds, _seed = 123_ parameter is set to 123 for reproducibility
#
# ###  Training the model

# %%
mtl_xgbr.fit(X_train, y_train.iloc[:,:2])
mtl_xgbc.fit(X_train, y_train.iloc[:,2:])
# Out:
# [10:31:42] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [10:31:43] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               gpu_id=None, grow_policy=None,
# ...

# %% [markdown]
# ### Assess the model's quality
# In order to asses the model quality we have to do it for each model because scoring the model doesn't work on a multiple output model, therefore we create the same model separated to asses each model quality.
#
# The quality of a XGBoost regressor can be expressed as its _mean squared error_, _root mean squarred error_, _mean absolute error_ obtained as follows:

# %%
reg_out = mtl_xgbr.predict(X_test)
clf_out = mtl_xgbc.predict(X_test)

# %%
pred_building = [x[0] for x in clf_out]
pred_floor = [x[1] for x in clf_out]

pred_latitude = [x[0] for x in reg_out]
pred_longitude = [x[1] for x in reg_out]

# %% [markdown]
# Mean Squared Error (MSE): It calculates the average squared difference between the predicted and actual values. Lower values indicate better performance.

# %%
mse_longitude = mean_squared_error(y_test['LONGITUDE'], pred_longitude)
r2_longitude_xgb = r2_score(y_test['LONGITUDE'], pred_longitude)
mse_latitude = mean_squared_error(y_test['LATITUDE'], pred_latitude)
r2_latitude_xgb = r2_score(y_test['LATITUDE'], pred_latitude)

print("Mean Squared Error (MSE) - Longitude:", mse_longitude)
print("R-squared (R²) score - Longitude:", r2_longitude_xgb)
print("Mean Squared Error (MSE) - Latitude:", mse_latitude)
print("R-squared (R²) score - Latitude:", r2_latitude_xgb)
# Out:
# Mean Squared Error (MSE) - Longitude: 0.008228976963822692
# R-squared (R²) score - Longitude: 0.9105490908777807
# Mean Squared Error (MSE) - Latitude: 0.007328629803346987
# R-squared (R²) score - Latitude: 0.8904123069546082

# %% [markdown]
# The quality of a XGBoost classifiers can be expressed as its _accuracy_ obtained as follows:

# %%
accuracy_floor_xgb = accuracy_score(y_test['FLOOR'], pred_floor)
accuracy_building_xgb = accuracy_score(y_test['BUILDINGID'], pred_building)

print("Accuracy (Floor):", accuracy_floor_xgb)
print("Accuracy (Building ID):", accuracy_building_xgb)
# Out:
# Accuracy (Floor): 0.9081908190819082
# Accuracy (Building ID): 0.9981998199819982

# %% [markdown]
# ## Building a Random Forest Classifier and Regressor using scikit-learn library
#
# A [Random Forest Regressor](https://en.wikipedia.org/wiki/Random_forest) is a type of machine learning algorithm used for prediction tasks that involves making continuous numerical predictions. It works by combining multiple decision trees and using them to make predictions. Each decision tree is trained on a subset of the data and uses a random set of features to make splits, which helps to reduce overfitting and improve generalization performance. The predictions made by each individual tree are then averaged to produce the final prediction.
#
# A [Random Forest Classifier](https://en.wikipedia.org/wiki/Random_forest)is a machine learning algorithm used for classification tasks. It combines multiple decision trees, each trained on a random subset of the data and using a random set of features, to make predictions. The final prediction is determined through majority voting among the individual trees.
#
# [1#source](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# [2#source](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfr = RandomForestRegressor(n_estimators=100, random_state=42)

mtl_rfr = MultiOutputRegressor(rfr)
mtl_rfc = MultiOutputClassifier(rfc)

# %% [markdown]
# [Random forest regressor](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html) is less prone to overfitting than a DecisionTreeRegressor, as it combines the predictions of multiple trees and thereby reduces the variance in the predictions.
#
# ###  Training the model

# %%
mtl_rfr.fit(X_train, y_train.iloc[:,:2])
mtl_rfc.fit(X_train, y_train.iloc[:,2:])
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(random_state=42))

# %% [markdown]
# ### Assess the model's quality
#
# The quality of a random forest regressor can be expressed as its _mean squared error_, accuracy_, _r2_, _mean absolute error_ obtained as follows:

# %%
reg_out = mtl_rfr.predict(X_test)
clf_out = mtl_rfc.predict(X_test)

# %%
pred_building = [x[0] for x in clf_out]
pred_floor = [x[1] for x in clf_out]

pred_lat = [x[0] for x in reg_out]
pred_long = [x[1] for x in reg_out]

# %%
mse_longitude = mean_squared_error(y_test['LONGITUDE'], pred_longitude)
r2_longitude_rf = r2_score(y_test['LONGITUDE'], pred_longitude)
mse_latitude = mean_squared_error(y_test['LATITUDE'], pred_latitude)
r2_latitude_rf = r2_score(y_test['LATITUDE'], pred_latitude)

print("Mean Squared Error (MSE) - Longitude:", mse_longitude)
print("R-squared (R²) score - Longitude:", r2_longitude_rf)
print("Mean Squared Error (MSE) - Latitude:", mse_latitude)
print("R-squared (R²) score - Latitude:", r2_latitude_rf)
# Out:
# Mean Squared Error (MSE) - Longitude: 0.008228976963822692
# R-squared (R²) score - Longitude: 0.9105490908777807
# Mean Squared Error (MSE) - Latitude: 0.007328629803346987
# R-squared (R²) score - Latitude: 0.8904123069546082

# %% [markdown]
# The quality of a random forest clasiffier can be expressed as its _accuracy_ obtained as follows:

# %%
accuracy_floor_rf = accuracy_score(y_test['FLOOR'], pred_floor)
accuracy_building_rf = accuracy_score(y_test['BUILDINGID'], pred_building)

print("Accuracy (Floor):", accuracy_floor_rf)
print("Accuracy (Building ID):", accuracy_building_rf)
# Out:
# Accuracy (Floor): 0.90999099909991
# Accuracy (Building ID): 0.9990999099909991

# %% [markdown]
# ## Building a K-Nearest Neighbors (KNN) Classifier and Regressor model
#
# In KNN, the prediction of a new data point is based on the majority vote or averaging of the target values of its K nearest neighbors in the feature space.

# %%
k = 3
knn_continuous = KNeighborsRegressor(n_neighbors=3)
knn_categorical = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ###  Training the model

# %%
knn_continuous.fit(X_train, y_train.iloc[:,:2])
knn_categorical.fit(X_train, y_train.iloc[:,2:])
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Assess the model's quality
#
# The quality of a knn can be expressed as its _mean squared error_, accuracy_, _r2_, _mean absolute error_ obtained as follows:

# %%
reg_out = knn_continuous.predict(X_test)
clf_out = knn_categorical.predict(X_test)

# %%
pred_building = [x[0] for x in clf_out]
pred_floor = [x[1] for x in clf_out]

pred_lat = [x[0] for x in reg_out]
pred_long = [x[1] for x in reg_out]

# %%
mse_longitude = mean_squared_error(y_test['LONGITUDE'], pred_longitude)
r2_longitude_knn = r2_score(y_test['LONGITUDE'], pred_longitude)
mse_latitude = mean_squared_error(y_test['LATITUDE'], pred_latitude)
r2_latitude_knn = r2_score(y_test['LATITUDE'], pred_latitude)

print("Mean Squared Error (MSE) - Longitude:", mse_longitude)
print("R-squared (R²) score - Longitude:", r2_longitude_knn)
print("Mean Squared Error (MSE) - Latitude:", mse_latitude)
print("R-squared (R²) score - Latitude:", r2_latitude_knn)
# Out:
# Mean Squared Error (MSE) - Longitude: 0.008228976963822692
# R-squared (R²) score - Longitude: 0.9105490908777807
# Mean Squared Error (MSE) - Latitude: 0.007328629803346987
# R-squared (R²) score - Latitude: 0.8904123069546082

# %% [markdown]
# The quality of a knn clasiffier can be expressed as its _accuracy_ obtained as follows:

# %%
accuracy_floor_knn = accuracy_score(y_test['FLOOR'], pred_floor)
accuracy_building_knn = accuracy_score(y_test['BUILDINGID'], pred_building)

print("Accuracy (Floor):", accuracy_floor_knn)
print("Accuracy (Building ID):", accuracy_building_knn)
# Out:
# Accuracy (Floor): 0.8424842484248425
# Accuracy (Building ID): 0.9954995499549955

# %% [markdown]
# ## Comparison Matrix
#
# This is where I plot a matrix to compare the models accuracy scores.

# %%
scores = {
    'Model': ['XGBoost', 'Random Forest', 'KNN'],
    'R2 Longitude': [r2_longitude_xgb, r2_longitude_rf, r2_longitude_knn],
    'R2 Latitude': [r2_latitude_xgb, r2_latitude_rf, r2_latitude_knn],
    'Accuracy Floor': [accuracy_floor_xgb, accuracy_floor_rf, accuracy_floor_knn],
    'Accuracy Building': [accuracy_building_xgb, accuracy_building_rf, accuracy_building_knn]
}

scores_df = pd.DataFrame(scores)

scores_df
# Out:
#            Model  R2 Longitude  R2 Latitude  Accuracy Floor  Accuracy Building
# 0        XGBoost      0.910549     0.890412        0.908191             0.9982
# 1  Random Forest      0.910549     0.890412        0.909991             0.9991
# 2            KNN      0.910549     0.890412        0.842484             0.9955

# %% [markdown]
# ## Conclusion
#
# I am pretty satisfied with the models as they are somewhat relaiable on. The best models seems to be the Random Forest as it scores the highest accuracy scores. A good use-case would be to asset the models accuracy in other ways and maybe also tune some of the models.
#
# Understanding the data and ploting it came up to be a challanging task but I gained lot of insights and learned a lot of new things, also worth mentioning that this dataset would fit more in a graph rather than a matrix.
#
# ### What I learned
#
# I learned how indoor/outdoor positioning systems work and the problems they encounter. I also learned how the Received Signal Strength Indicator (RSSI) works and what it is.
#
# Furthermore, I learned how to properly normalize data in this particular use-case, and I realized how important it is. It was a tricky problem to tackle since the data samples were confusing, I modeled an XGBoost model which I had never used before.
#
# Additionally I went and learned graph neural networks, bipartite graphs and how do they work.
#
# ### Thank you!

# %% [markdown]
# # REFERANCES
#
#     Wikipedia. (n.d.). Data modeling. Retrieved from https://en.wikipedia.org/wiki/Data_modeling
#
#     Ferreira, N. (n.d.). From Data to Viz. Retrieved from https://www.data-to-viz.com/
#
#     Kaggle Tirkey, D. (n.d.). Indoor Localization. Retrieved from https://www.kaggle.com/code/tirkeydivyanshu/indoor-localization
#
#     UCI Machine Learning Repository Torres-Sospedra, J., Montoliu, R., Belmonte, O., Huerta, J., & Morell, A. (n.d.). UJIIndoorLoc: A new multi-building and multi-floor database for WLAN fingerprint-based indoor localization problems. Retrieved from https://archive.ics.uci.edu/dataset/310/ujiindoorloc
#
#     ResearchGate Torres-Sospedra, J., Montoliu, R., & Belmonte, O. (n.d.). UJIIndoorLoc: A new multi-building and multi-floor database for WLAN fingerprint-based indoor localization problems. Retrieved from https://www.researchgate.net/publication/283894296_UJIIndoorLoc_A_new_multi-building_and_multi-floor_database_for_WLAN_fingerprint-based_indoor_localization_problems
#
#     Wikipedia Received Signal Strength Indicator. (n.d.). In Wikipedia. Retrieved from https://en.wikipedia.org/wiki/Received_signal_strength_indicator
#
#     XGBoost Documentation XGBoost. (n.d.). Retrieved from https://xgboost.readthedocs.io/en/stable/
#
#     Wikipedia Random Forest. (n.d.). In Wikipedia. Retrieved from https://en.wikipedia.org/wiki/Random_forest
#
#     Wikipedia K-Nearest Neighbors Algorithm. (n.d.). In Wikipedia. Retrieved from https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm
